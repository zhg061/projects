# %% [markdown]
# # Mapping SDPD data with python

# %% [markdown]
# ### Preparation: installing `folium`
#
# Plotting mapping data requires using a python library called `folium`. To install this library, type the following command in a terminal:
# ```
# pip install --upgrade --user folium
# ```
# Answer `Y` to confirm you want the library installed. Once finished, you can import the library in your notebooks.

# %%
# %matplotlib inline
from datascience import *
import folium
import numpy as np
import json

folium.__version__
# Out:
# '0.6.0'

# %% [markdown]
# ### Import the traffic stops data and the collision data

# %%
stops_path = '../1.messy_data/data/vehicle_stops_2016_datasd.csv'
collisions_path = '../2.measurements_and_metrics/data/pd_collisions_datasd.csv'

# %%
stops = Table.read_table(stops_path)
collisions = Table.read_table(collisions_path)

# %% [markdown]
# ### Counting the number of traffic stops by police service area

# %%
stops.show(10)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>stop_id</th> <th>stop_cause</th> <th>service_area</th> <th>subject_race</th> <th>subject_sex</th> <th>subject_age</th> <th>timestamp</th> <th>stop_date</th> <th>stop_time</th> <th>sd_resident</th> <th>arrested</th> <th>searched</th> <th>obtained_consent</th> <th>contraband_found</th> <th>property_seized</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1308198</td> <td>Equipment Violation</td> <td>530         </td> <td>W           </td> <td>M          </td> <td>28         </td> <td>2016-01-01 00:06:00</td> <td>2016-01-01</td> <td>0:06     </td> <td>Y          </td> <td>N       </td> <td>N       </td> <td>N               </td> <td>N               </td> <td>N              </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1308172</td> <td>Moving Violation   </td> <td>520         </td> <td>B           </td> <td>M          </td> <td>25         </td> <td>2016-01-01 00:10:00</td> <td>2016-01-01</td> <td>0:10     </td> <td>N          </td> <td>N       </td> <td>N       </td> <td>nan             </td> <td>nan             </td> <td>nan            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1308171</td> <td>Moving Violation   </td> <td>110         </td> <td>H           </td> <td>F          </td> <td>31         </td> <td>2016-01-01 00:14:00</td> <td>2016-01-01</td> <td>0:14     </td> <td>nan        </td> <td>nan     </td> <td>nan     </td> <td>nan             </td> <td>nan             </td> <td>nan            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1308170</td> <td>Moving Violation   </td> <td>Unknown     </td> <td>W           </td> <td>F          </td> <td>29         </td> <td>2016-01-01 00:16:00</td> <td>2016-01-01</td> <td>0:16     </td> <td>N          </td> <td>N       </td> <td>N       </td> <td>nan             </td> <td>nan             </td> <td>nan            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1308197</td> <td>Moving Violation   </td> <td>230         </td> <td>W           </td> <td>M          </td> <td>52         </td> <td>2016-01-01 00:30:00</td> <td>2016-01-01</td> <td>0:30     </td> <td>N          </td> <td>N       </td> <td>N       </td> <td>nan             </td> <td>nan             </td> <td>nan            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1308200</td> <td>Moving Violation   </td> <td>710         </td> <td>H           </td> <td>M          </td> <td>24         </td> <td>2016-01-01 00:30:00</td> <td>2016-01-01</td> <td>0:30     </td> <td>Y          </td> <td>N       </td> <td>N       </td> <td>nan             </td> <td>nan             </td> <td>nan            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1308174</td> <td>Moving Violation   </td> <td>Unknown     </td> <td>O           </td> <td>M          </td> <td>20         </td> <td>2016-01-01 00:35:00</td> <td>2016-01-01</td> <td>0:35     </td> <td>Y          </td> <td>N       </td> <td>N       </td> <td>nan             </td> <td>nan             </td> <td>nan            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1308199</td> <td>Moving Violation   </td> <td>440         </td> <td>H           </td> <td>M          </td> <td>50         </td> <td>2016-01-01 00:45:00</td> <td>2016-01-01</td> <td>0:45     </td> <td>Y          </td> <td>N       </td> <td>N       </td> <td>nan             </td> <td>nan             </td> <td>nan            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1308979</td> <td>Moving Violation   </td> <td>310         </td> <td>H           </td> <td>F          </td> <td>25         </td> <td>2016-01-01 01:03:00</td> <td>2016-01-01</td> <td> 1:03    </td> <td>Y          </td> <td>N       </td> <td>Y       </td> <td>N               </td> <td>N               </td> <td>N              </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1308965</td> <td>Moving Violation   </td> <td>240         </td> <td>W           </td> <td>F          </td> <td>23         </td> <td>2016-01-01 01:10:00</td> <td>2016-01-01</td> <td> 1:10    </td> <td>Y          </td> <td>N       </td> <td>N       </td> <td>nan             </td> <td>nan             </td> <td>nan            </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (103041 rows omitted)</p>

# %% [markdown]
# We need to clean the service_area field,
# 1. there are non-digits in the field
# 2. because of the non-digits, even the digits are of string type
#
# To join with our map, we have to clean this column.

# %%
type(stops.column('service_area').item(0))
# Out:
# str

# %%
def isdigit(x):
    return x.isdigit()

stops_cleaned = stops.where('service_area', isdigit)
stops_cleaned = stops_cleaned.with_column(
    'service_area', 
     stops_cleaned.column('service_area').astype(int)
    'subject_age',
    stops_cleaned.column('subject_age').astype(float)
)
# Out:
#   File "<ipython-input-27-0ffd1dfb6446>", line 8
#     'subject_age',
#                 ^
# SyntaxError: invalid syntax

# %%
stops_cleaned.column('service_area').item(0)
# Out:
# 530

# %%
stop_counts = stops_cleaned.group('service_area')
stop_counts
# Out:
# service_area | count
# 110          | 7273
# 120          | 8177
# 130          | 23
# 230          | 5602
# 240          | 6433
# 310          | 8074
# 320          | 4722
# 430          | 4018
# 440          | 4181
# 510          | 4937
# ... (12 rows omitted)

# %% [markdown]
# ### Load and clean the map

# %%
geo_path = 'data/pd_beats_datasd.geojson'

# %% [markdown]
# Now we need to load the geographical data and filter out the service areas that aren't present in our data.
# * The join key to the geojson for the stops data is `serv`
# * The join key to the geojson for the collisions data is `beat`

# %%
gj = json.load(open(geo_path))

# %% [markdown]
# An example region encoded in a geojson format (the list of coordinates are lat/long):

# %%
gj['features'][0]
# Out:
# {'geometry': {'coordinates': [[[-117.087138, 32.583822],
#     [-117.08695, 32.583007],
#     [-117.08693249, 32.58293112],
#     [-117.08686, 32.582617],
#     [-117.08648, 32.581573],
#     [-117.086201, 32.58091],
#     [-117.086047, 32.580678],
#     [-117.08595258, 32.58053575],
#     [-117.08567562, 32.58011851],
#     [-117.085585, 32.579982],
#     [-117.085417, 32.579739],
#     [-117.084812, 32.579065],
#     [-117.08475964, 32.57900662],
#     [-117.084725, 32.578968],
#     [-117.083637, 32.577854],
#     [-117.08227701, 32.57648368],
#     [-117.08224938, 32.57645654],
#     [-117.082146, 32.576355],
#     [-117.081926, 32.576137],
#     [-117.081774, 32.575953],
#     [-117.09272007, 32.57763606],
#     [-117.09272175, 32.57764973],
#     [-117.09272359, 32.57766338],
#     [-117.09272559, 32.57767702],
#     [-117.09272775, 32.57769064],
#     [-117.09270203, 32.57839718],
#     [-117.09269349, 32.57920254],
#     [-117.09268566, 32.58012942],
#     [-117.09268129, 32.58064558],
#     [-117.09268714, 32.58107037],
#     [-117.09269191, 32.58141783],
#     [-117.09271059, 32.58201412],
#     [-117.09270925, 32.58289364],
#     [-117.09269821, 32.58343792],
#     [-117.09268264, 32.58384755],
#     [-117.09079632, 32.58382746],
#     [-117.09041647, 32.58382456],
#     [-117.09001389, 32.5838218],
#     [-117.08893447, 32.58383404],
#     [-117.08780861, 32.58382668],
#     [-117.08753785, 32.58382765],
#     [-117.08737001, 32.5838286],
#     [-117.08727586, 32.58382592],
#     [-117.08722395, 32.58382444],
#     [-117.087138, 32.583822]]],
#   'type': 'Polygon'},
#  'properties': {'beat': 722,
#   'div': 7,
#   'name': 'NESTOR',
#   'objectid': 1,
#   'serv': 720},
#  'type': 'Feature'}

# %%
gj['features'] = [f for f in gj['features'] if f['properties']['serv'] in stop_counts.column('service_area')]

# %% [markdown]
# ### Create a map object, overlay the counts, and plot it!

# %%
stops_map = folium.Map(location=(32.7157, -117.1611), zoom_start=10)

# %%
stops_map.choropleth(
    geo_data=gj,
    data=stop_counts.to_df(),   # needs to be a pandas dataframe
    columns=['service_area', 'count'],
    fill_color = 'YlOrRd',
    fill_opacity = 0.5, 
    line_opacity = 0.2,
    key_on='feature.properties.serv',
)

# %% [markdown]
# Save the map to an `html` file. View the file by visiting the jupyter server page, selecting the file, and clicking `view` from the menu at top.

# %%
stops_map.save('stops.html')

# %% [markdown]
# ## Mapping the collisions data
#
# The collisions data is joined to the map using `police_beat` -- we need to assess and clean the data. Is it of `int` type?

# %%
collisions.column('police_beat')
# Out:
# array([113, 524, 437, ..., 246, 613, 821])

# %%
collision_counts = collisions.group('police_beat')

# %%
collision_counts.sort('count', descending=True)
# Out:
# police_beat | count
# 122         | 1347
# 242         | 839
# 813         | 811
# 313         | 809
# 124         | 732
# 627         | 636
# 115         | 623
# 521         | 617
# 315         | 610
# 611         | 573
# ... (132 rows omitted)

# %%
collision_map = folium.Map(location=(32.7157, -117.1611), zoom_start=10)

collision_map.choropleth(
    geo_data=gj,
    data=collision_counts.to_df(),   # needs to be a pandas dataframe
    columns=['police_beat', 'count'],
    fill_color = 'YlGn',
    fill_opacity = 0.5, 
    line_opacity = 0.2,
    threshold_scale=[0,300,600,900,1200,1500],
    key_on='feature.properties.beat',
)

# %%
collision_map.save('collisions.html')

# %% [markdown]
# # Copy this notebook and plot your own statistics by geography
# * Percentage of stops that result in a search.
# * Average age of drivers.
# * Percentage of traffic stops that occur at night.
# * Number of Hispanic/Black/White/Asian drivers pulled over.

# %%
result_stop = stops.group('searched')
result_stop_searched = result_stop.where('searched', are.equal_to('Y'))
result_stop_searched
# Out:
# searched | count
# Y        | 3972
