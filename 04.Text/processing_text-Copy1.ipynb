# %% [markdown]
# # Text Processing
#
# The file `UCSD tweets.csv` has a small number of tweets from August and September 2018 that contained the term "UCSD".  Let's analyze them!
#
# ### Steps
#
# Each step is explained in more detail below
# 1. Open the CSV and explore the data
# 2. Clean the data
# 3. Count word frequency
# 4. Sentiment analysis

# %%
# Imports
# %matplotlib inline

import numpy as np
from datascience import *

# %% [markdown]
# # 1. Open the CSV and explore the data
#
# ### Steps:
# * load the data from `data/UCSD tweets.csv`
# * Examine the data.  How many tweets are there?  How long is the shortest tweet?  Longest?

# %%
# you code here
tweets = Table().read_table("data/UCSD tweets.csv")
tweets
# Out:
# username       | date    | text
# @fox5sandiego  | Aug 27  | UCSD ranked 7th best school in US by Washington Monthly
# @KamaFaye      | Sep 1   | it physically pains me that UCSD doesn’t have a football ...
# @team10news_CA | Sep 2   | A card mis-judged a parking space and over-ran a parking ...
# @SapnaKmd      | Sep 2   | Almost 50% increase in #PedsICU engagement from last wee ...
# @kabeerthirty  | Aug 27T | here’s a tinge of classism in saying SDSU should make do ...
# @KNBKSoshihan  | Sep 2   | This past weekend we observed the 25th anniversary of th ...
# @jessiejpg     | Aug 29  | I HATE UCSD SO MUCH THEYRE SO ANNOYING OHHHHH MY GOD
# @Juanickers    | Aug 29  | LMFAOOO UCSD JUST CALLED ME ASKING IF I COULD MAKE A $25 ...
# @savvymunoz    | Aug 31  | I chose UCSD because it has the best fb meme group
# @Yokwellzy     | Aug 31  | High key excited to be going back to UCSD 💙💛
# ... (30 rows omitted)

# %%
# your code here
tweets.num_rows
length = []
for i in range(40):
    length.append(len(tweets.column('text')[i]))
tweets.with_column('length', length).sort('length').column('length').item(0)
tweets.with_column('length', length).sort('length', descending=True).column('length').item(0)
# Out:
# 278

# %% [markdown]
# # 2. Clean the data
#
# ### Filter out tweets that don't have `UCSD` in the text
#
# The Twitter search matches on both username and tweet text.  We want just the ones that have a match in the tweet itself.  The result should be a new dataframe with the subset of matching tweets.
#
# * create functions to apply to your table and clean your data
# * use where clauses to filter

# %%
# your code here
tweets.where('text', are.containing('UCSD'))
# Out:
# username       | date    | text
# @fox5sandiego  | Aug 27  | UCSD ranked 7th best school in US by Washington Monthly
# @KamaFaye      | Sep 1   | it physically pains me that UCSD doesn’t have a football ...
# @team10news_CA | Sep 2   | A card mis-judged a parking space and over-ran a parking ...
# @SapnaKmd      | Sep 2   | Almost 50% increase in #PedsICU engagement from last wee ...
# @kabeerthirty  | Aug 27T | here’s a tinge of classism in saying SDSU should make do ...
# @KNBKSoshihan  | Sep 2   | This past weekend we observed the 25th anniversary of th ...
# @jessiejpg     | Aug 29  | I HATE UCSD SO MUCH THEYRE SO ANNOYING OHHHHH MY GOD
# @Juanickers    | Aug 29  | LMFAOOO UCSD JUST CALLED ME ASKING IF I COULD MAKE A $25 ...
# @savvymunoz    | Aug 31  | I chose UCSD because it has the best fb meme group
# @Yokwellzy     | Aug 31  | High key excited to be going back to UCSD 💙💛
# ... (23 rows omitted)

# %% [markdown]
# ## Check for duplicates
#
# See if any of the tweets have exactly the same text.  If so, are they true duplicates?  Does it make sense to remove them?

# %%
# your code here
tweets.group('text').sort('count', descending=True)
# Out:
# text                                                         | count
# Great opportunity to take the ATOM & ASSET trauma course ... | 2
# 📈  405.60 parts per million (ppm) #CO2 in the atmosphere ... | 1
# it physically pains me that UCSD doesn’t have a football ... | 1
# i can’t believe that in a month summer manar and i will  ... | 1
# here’s a tinge of classism in saying SDSU should make do ... | 1
# Very interesting work from UCSD Neutrophil nanosponges s ... | 1
# USC rejected me and UCSD accepted me so disappointed.        | 1
# UCSD women's soccer wins home opener as McManus eats piz ... | 1
# UCSD ranked 7th best school in US by Washington Monthly      | 1
# UCSD REINSTATED ME IT’S MODELO TIME                          | 1
# ... (29 rows omitted)

# %% [markdown]
# # 2. Count Words
#
# We want to find out what the most frequent words are, so we need to split things up.  In text this is called tokenizing.
#
# ### Steps
#
# 1. Make a single long string with all of the tweet text.  Make sure to put spaces between them!
# 2. Split the tweets into a list of words using `.split()`
# 3. Print out the first 20 words to make sure it looks like what you think it should.
#
# How many words are there all together?  How many distinct words? (remember `set()`)

# %%
# your code here
string = ''
for i in range(40):
    string = string + tweets.column('text')[i] + " "
split = string.split()
print(split[:20])
print(len(split))
len(np.unique(split))
len(set(split))
# Out:
# ['UCSD', 'ranked', '7th', 'best', 'school', 'in', 'US', 'by', 'Washington', 'Monthly', 'it', 'physically', 'pains', 'me', 'that', 'UCSD', 'doesn’t', 'have', 'a', 'football']
# 875
# 580

# %% [markdown]
# ### Remove short words
#
# Short words are really common, and aren't super helpful for comparing word count.  Usually it is best to remove what are called "stop words", which include things like "of", "a", "in", etc.  In this case we will just remove all words that are less than three charecters long.
#
# The result should be a new list of words.  How many total?  How many unique?

# %%
# Your code here
long_words = []
for i in range(len(split)):
    if len(split[i]) >= 3:
        long_words.append(split[i])
long_words
# Out:
# ['UCSD',
#  'ranked',
#  '7th',
#  'best',
#  'school',
#  'Washington',
#  'Monthly',
#  'physically',
#  'pains',
#  'that',
#  'UCSD',
#  'doesn’t',
#  'have',
#  'football',
#  'team',
#  'card',
#  'mis-judged',
#  'parking',
#  'space',
#  'and',
#  'over-ran',
#  'parking',
#  'lot',
#  'the',
#  'process',
#  'taking',
#  'out',
#  'about',
#  'about',
#  'feet',
#  'chain-link',
#  'fence',
#  'this',
#  'morning',
#  'the',
#  'Nobel',
#  'apartments',
#  'the',
#  'UCSD',
#  'area.',
#  'Around',
#  '9:10',
#  'I...',
#  'https://www.facebook.com/JAMIESCOTTmobile/posts/2177799288905402',
#  'Almost',
#  '50%',
#  'increase',
#  '#PedsICU',
#  'engagement',
#  'from',
#  'last',
#  'week',
#  '>1000',
#  'tweets!👌🏽Special',
#  'shoutout',
#  '@DrKanaris',
#  'for',
#  'the',
#  'new',
#  'Friday',
#  '#PedsICU',
#  'quiz',
#  'tradition',
#  '@UCSD_PICU',
#  'for',
#  'the',
#  'great',
#  '#meded!',
#  '@healthhashtags',
#  '#medtwitter',
#  'here’s',
#  'tinge',
#  'classism',
#  'saying',
#  'SDSU',
#  'should',
#  'make',
#  'with',
#  'its',
#  '283',
#  'acres',
#  'while',
#  'UCSD',
#  'accommodates',
#  'roughly',
#  'the',
#  'same',
#  'number',
#  'students',
#  'its',
#  'idyllic',
#  '2141-acre',
#  'campus',
#  'This',
#  'past',
#  'weekend',
#  'observed',
#  'the',
#  '25th',
#  'anniversary',
#  'the',
#  'UCSD',
#  'Iaido',
#  'club',
#  'San',
#  'Diego.',
#  'The',
#  'training',
#  'was',
#  'dedicated',
#  'our',
#  'past',
#  'teachers.',
#  'HATE',
#  'UCSD',
#  'MUCH',
#  'THEYRE',
#  'ANNOYING',
#  'OHHHHH',
#  'GOD',
#  'LMFAOOO',
#  'UCSD',
#  'JUST',
#  'CALLED',
#  'ASKING',
#  'COULD',
#  'MAKE',
#  '$250',
#  'HUNDRED',
#  'FIFTY',
#  'DOLLAR)',
#  'DONATION',
#  'LIKE',
#  'BITCH',
#  'HOW',
#  'BOUT',
#  'YOU',
#  'PAY',
#  'chose',
#  'UCSD',
#  'because',
#  'has',
#  'the',
#  'best',
#  'meme',
#  'group',
#  'High',
#  'key',
#  'excited',
#  'going',
#  'back',
#  'UCSD',
#  'OMG!!',
#  'Got',
#  'THE',
#  'CALL',
#  'for',
#  'lungs',
#  '5:30am!',
#  'Waiting',
#  'UCSD',
#  'make',
#  'sure',
#  'they',
#  'are',
#  'go..if',
#  'could',
#  'have',
#  'new',
#  'lungs',
#  'TODAY!!',
#  '😂😂🦋',
#  '#cysticfibrosis',
#  '#trandplanttime',
#  'Did',
#  'ya’ll',
#  'know',
#  'was',
#  'initially',
#  'waitlisted',
#  'MIT',
#  'and',
#  'straight',
#  'rejected',
#  'from',
#  'UCSD',
#  'for',
#  'grad',
#  'school.',
#  'Just',
#  'case',
#  'you',
#  'were',
#  'thinking',
#  'about',
#  'giving',
#  'up.',
#  'UCSD',
#  "women's",
#  'soccer',
#  'wins',
#  'home',
#  'opener',
#  'McManus',
#  'eats',
#  'pizza',
#  'http://dlvr.it/Qhr6Qp',
#  'can’t',
#  'believe',
#  'that',
#  'month',
#  'summer',
#  'manar',
#  'and',
#  'will',
#  'all',
#  'being',
#  'going',
#  'the',
#  'same',
#  'school...',
#  'ucsd?',
#  'more',
#  'like',
#  'tumblr',
#  'university',
#  '@UCSanDiego',
#  'named',
#  'No.1',
#  'public',
#  'university',
#  'the',
#  'nation',
#  'Washington',
#  'Monthly',
#  'for',
#  'its',
#  'contributions',
#  'social',
#  'mobility',
#  'research',
#  'and',
#  'public',
#  'service.',
#  '@washmonthly',
#  '#ucsd',
#  '#TritonPride',
#  'http://ow.ly/TKnC30lzFBs',
#  'USC',
#  'rejected',
#  'and',
#  'UCSD',
#  'accepted',
#  'disappointed.',
#  "Summer's",
#  'winding',
#  'down',
#  '...',
#  'how',
#  'many',
#  'new',
#  'UCSD',
#  'Bioengineering',
#  'students',
#  'become',
#  'alums',
#  'this',
#  'coming',
#  'year?',
#  'Good',
#  'luck',
#  'you',
#  'guys!',
#  'can’t',
#  'seem',
#  'find',
#  'good',
#  'time',
#  'remind',
#  'everyone',
#  'that',
#  'the',
#  'inaugural',
#  '#PedsICU',
#  'Journal',
#  'Club',
#  'will',
#  'commence',
#  'Sept.',
#  'central',
#  'time.',
#  'Saturday',
#  'isn’t',
#  'but',
#  'I’ll',
#  'later.',
#  'UCSD',
#  'REINSTATED',
#  'IT’S',
#  'MODELO',
#  'TIME',
#  'Great',
#  'opportunity',
#  'take',
#  'the',
#  'ATOM',
#  'ASSET',
#  'trauma',
#  'courses',
#  'the',
#  'the',
#  '@CFS_UCSD',
#  'facility',
#  'during',
#  '#AAST2018',
#  '#wtc2018',
#  '@UCSDsurgery',
#  'Jumping',
#  'for',
#  'joy',
#  'this',
#  'easy',
#  'Monday.',
#  '#laborday',
#  '#holiday',
#  '#sandiego',
#  '#california',
#  'UCSD',
#  'University',
#  'California',
#  'San',
#  'Diego',
#  'https://www.instagram.com/p/BnRkQwEHJiu/?utm_source=ig_twitter_share&igshid=q4h7a4a4khwn',
#  'This',
#  'weird',
#  'story.',
#  'note',
#  'UCSD’s',
#  'Athletic',
#  'Director',
#  'Earl',
#  'Edwards',
#  'father',
#  'Orlando',
#  'City',
#  'Earl',
#  'Edwards',
#  'Jr.',
#  'Second',
#  '#NASPA',
#  'proposal',
#  'submitted.',
#  'This',
#  'one',
#  'collaboration',
#  'with',
#  'dear',
#  'friends',
#  'and',
#  'colleagues',
#  'who',
#  'co-organized',
#  'the',
#  'first-gen',
#  'symposium',
#  'hosted',
#  '@UCSD.',
#  '@AleceAnderson',
#  '@ucfirstgen',
#  '@UCdiverse',
#  '#teamworkmakesthedreamwork',
#  'Very',
#  'interesting',
#  'work',
#  'from',
#  'UCSD',
#  'Neutrophil',
#  'nanosponges',
#  'soak',
#  'proteins',
#  'that',
#  'promote',
#  'rheumatoid',
#  'arthritis',
#  'Part',
#  'one',
#  'our',
#  'series',
#  "@UCSD_EDC's",
#  'Dr.',
#  'Walter',
#  'Kaye',
#  'Anorexia',
#  'Current',
#  'Prior',
#  'Research:',
#  'Implications',
#  'for',
#  'Improved',
#  'Treatment',
#  'fom',
#  'Eating',
#  'Disorder',
#  'Hope’s',
#  'Virtual',
#  'Conference',
#  '“Anorexia',
#  'Hope',
#  'Healing',
#  '2018”',
#  "Men's",
#  'Water',
#  'Polo',
#  'Tops',
#  'Chapman',
#  'Highlight',
#  'Day',
#  'Two',
#  'UCSD',
#  'Triton',
#  'Invite',
#  'http://www.goredlands.com/x/zopca',
#  '#URDawgs',
#  '#TimeToShine',
#  '405.60',
#  'parts',
#  'per',
#  'million',
#  '(ppm)',
#  '#CO2',
#  'the',
#  'atmosphere',
#  'September',
#  '2018',
#  '#Scripps',
#  '#UCSD',
#  'Mauna',
#  'Loa',
#  'data',
#  'graphic:',
#  'https://scripps.ucsd.edu/programs/keelingcurve/',
#  'Also',
#  'view',
#  'daily',
#  'CO2',
#  'updates',
#  'https://www.co2.earth/daily-co2',
#  'Thank',
#  'you',
#  'all',
#  'the',
#  'teams',
#  'supporters',
#  'who',
#  'made',
#  'down',
#  'Jolla',
#  'for',
#  'the',
#  'annual',
#  '#TritonInvite.',
#  'always',
#  'exciting',
#  'event',
#  'are',
#  'grateful',
#  'host',
#  'the',
#  'start',
#  'the',
#  '2018',
#  'season.',
#  'The',
#  'next',
#  'home',
#  'game',
#  'for',
#  '@UCSDTritonsMWP',
#  'will',
#  'September',
#  '19th',
#  '6pm',
#  'against',
#  '@LBSUWaterPolo!',
#  "can't",
#  'believe',
#  'have',
#  'the',
#  'privilege',
#  'say',
#  'that',
#  'student',
#  'the',
#  'Jacob',
#  'Sartorius',
#  'School',
#  'Engineering',
#  'UCSD.',
#  'Congrats',
#  'junior',
#  'forward',
#  'Brandon',
#  'Angel',
#  'his',
#  'offer',
#  'from',
#  'future',
#  'Big',
#  'West',
#  'school',
#  'UCSD!',
#  '#GoFalcons',
#  'One',
#  'first',
#  '#retina',
#  'paintings',
#  'that',
#  'now',
#  'hangs',
#  '#UCSD.',
#  'Commissioned',
#  '2012.',
#  '#goldleaf',
#  '#art',
#  'https://buff.ly/LGtoGE',
#  'More',
#  'the',
#  'men',
#  'finishing',
#  'second',
#  'and',
#  'the',
#  'women',
#  'taking',
#  'third',
#  "today's",
#  'Mark',
#  'Covert',
#  'Classic',
#  'open',
#  'the',
#  'season.',
#  'http://www.ucsdtritons.com/ViewArticle.dbml?DB_OEM_ID=5800&ATCLID=211770300',
#  '#GoTritons',
#  '#PHMFellowsJC',
#  'hosting',
#  'our',
#  'first',
#  'journal',
#  'club',
#  'this',
#  'month',
#  'too!',
#  'Tues',
#  'Sept',
#  'EST.',
#  'Would',
#  'love',
#  'have',
#  '#PedsICU',
#  'join',
#  'discuss',
#  'the',
#  'recently',
#  'published',
#  '@JAMA_current',
#  'paper',
#  'the',
#  'sepsis',
#  'mandate.',
#  'More',
#  'details',
#  'come',
#  'this',
#  'Tuesday!',
#  'Great',
#  'opportunity',
#  'take',
#  'the',
#  'ATOM',
#  'ASSET',
#  'trauma',
#  'courses',
#  'the',
#  'the',
#  '@CFS_UCSD',
#  'facility',
#  'during',
#  '#AAST2018',
#  '#wtc2018',
#  '@UCSDsurgery',
#  'Live',
#  'from',
#  'India',
#  'travel',
#  'blog',
#  'has',
#  'returned.',
#  'This',
#  'goes',
#  'back',
#  '2005',
#  'and',
#  'includes',
#  'all',
#  'China',
#  'travels',
#  'that',
#  'were',
#  'long',
#  'ago',
#  'cross',
#  'posted',
#  'the',
#  'Node:',
#  'http://phdtraveler.blogspot.com',
#  '2019',
#  'Bryce',
#  'Pope',
#  '(Torrey',
#  'Pines)',
#  'has',
#  'committed',
#  'UCSD.',
#  '#gpnation',
#  'Did',
#  'you',
#  'know',
#  'that',
#  '@UCSDHealth',
#  '#surgeons',
#  'have',
#  'performed',
#  '>3900',
#  '#pulmonary',
#  'thromboendarterectomy',
#  'procedures',
#  'which',
#  'remove',
#  'deadly',
#  'clots',
#  'from',
#  'the',
#  'lungs.',
#  'Thank',
#  'you',
#  'Dr.',
#  'Michael',
#  'Madani',
#  'for',
#  'leading',
#  'the',
#  'program',
#  'helping',
#  'patients',
#  'live',
#  'longer',
#  'healthier',
#  'lives.',
#  '@STS_CTsurgery',
#  '@annalsthorsurg',
#  'The',
#  'new',
#  'MZmine-GNPS',
#  'tutorial',
#  'making',
#  'day',
#  'thanks',
#  '@GNPS_UCSD!',
#  '#RealTimeChem',
#  '#chemtwitter',
#  'Stats',
#  '101',
#  'Deep',
#  'Thoughts',
#  '#pedsICU',
#  'Classroom',
#  'management',
#  '@UHS_UCSD.',
#  'Setting',
#  'expectations',
#  'for',
#  'different',
#  'types',
#  'student',
#  'groupings.']

# %% [markdown]
# # 3. Count word frequency
#
# You can use a dictionary to create a categorical distribution of the words in a sentence:

# %%
my_sentence = 'Jack be nimble, Jack be quick, Jack jump over the candlestick'
my_words = my_sentence.split()

categorical_distribution = {} # empty dictionary
for word in my_words:
    if word in categorical_distribution:
        categorical_distribution[word] = categorical_distribution[word] + 1
    else:
        categorical_distribution[word] = 1
        
categorical_distribution
# Out:
# {'Jack': 3,
#  'be': 2,
#  'candlestick': 1,
#  'jump': 1,
#  'nimble,': 1,
#  'over': 1,
#  'quick,': 1,
#  'the': 1}

# %% [markdown]
# Create a categorical distribution of words for all tweets.
# * Are you surprised by the most common?

# %%
# your code here
categorical_distribution_twitter = {} # empty dictionary
for i in long_words:
    if i in categorical_distribution_twitter:
        categorical_distribution_twitter[i] = categorical_distribution_twitter[i] + 1
    else:
        categorical_distribution_twitter[i] = 1
categorical_distribution_twitter  
#D = dictionary
#def sortfun(x):
    #return x[i]
#categorical_distribution_twitter.sorted(D, key=sortfun, reversed=True)
# Out:
# {'#AAST2018': 2,
#  '#CO2': 1,
#  '#GoFalcons': 1,
#  '#GoTritons': 1,
#  '#NASPA': 1,
#  '#PHMFellowsJC': 1,
#  '#PedsICU': 4,
#  '#RealTimeChem': 1,
#  '#Scripps': 1,
#  '#TimeToShine': 1,
#  '#TritonInvite.': 1,
#  '#TritonPride': 1,
#  '#UCSD': 1,
#  '#UCSD.': 1,
#  '#URDawgs': 1,
#  '#art': 1,
#  '#california': 1,
#  '#chemtwitter': 1,
#  '#cysticfibrosis': 1,
#  '#goldleaf': 1,
#  '#gpnation': 1,
#  '#holiday': 1,
#  '#laborday': 1,
#  '#meded!': 1,
#  '#medtwitter': 1,
#  '#pedsICU': 1,
#  '#pulmonary': 1,
#  '#retina': 1,
#  '#sandiego': 1,
#  '#surgeons': 1,
#  '#teamworkmakesthedreamwork': 1,
#  '#trandplanttime': 1,
#  '#ucsd': 1,
#  '#wtc2018': 2,
#  '$250': 1,
#  '(Torrey': 1,
#  '(ppm)': 1,
#  '...': 1,
#  '101': 1,
#  '19th': 1,
#  '2005': 1,
#  '2012.': 1,
#  '2018': 2,
#  '2018”': 1,
#  '2019': 1,
#  '2141-acre': 1,
#  '25th': 1,
#  '283': 1,
#  '405.60': 1,
#  '50%': 1,
#  '5:30am!': 1,
#  '6pm': 1,
#  '7th': 1,
#  '9:10': 1,
#  '>1000': 1,
#  '>3900': 1,
#  '@AleceAnderson': 1,
#  '@CFS_UCSD': 2,
#  '@DrKanaris': 1,
#  '@GNPS_UCSD!': 1,
#  '@JAMA_current': 1,
#  '@LBSUWaterPolo!': 1,
#  '@STS_CTsurgery': 1,
#  '@UCSD.': 1,
#  '@UCSDHealth': 1,
#  '@UCSDTritonsMWP': 1,
#  "@UCSD_EDC's": 1,
#  '@UCSD_PICU': 1,
#  '@UCSDsurgery': 2,
#  '@UCSanDiego': 1,
#  '@UCdiverse': 1,
#  '@UHS_UCSD.': 1,
#  '@annalsthorsurg': 1,
#  '@healthhashtags': 1,
#  '@ucfirstgen': 1,
#  '@washmonthly': 1,
#  'ANNOYING': 1,
#  'ASKING': 1,
#  'ASSET': 2,
#  'ATOM': 2,
#  'Almost': 1,
#  'Also': 1,
#  'Angel': 1,
#  'Anorexia': 1,
#  'Around': 1,
#  'Athletic': 1,
#  'BITCH': 1,
#  'BOUT': 1,
#  'Big': 1,
#  'Bioengineering': 1,
#  'Brandon': 1,
#  'Bryce': 1,
#  'CALL': 1,
#  'CALLED': 1,
#  'CO2': 1,
#  'COULD': 1,
#  'California': 1,
#  'Chapman': 1,
#  'China': 1,
#  'City': 1,
#  'Classic': 1,
#  'Classroom': 1,
#  'Club': 1,
#  'Commissioned': 1,
#  'Conference': 1,
#  'Congrats': 1,
#  'Covert': 1,
#  'Current': 1,
#  'DOLLAR)': 1,
#  'DONATION': 1,
#  'Day': 1,
#  'Deep': 1,
#  'Did': 2,
#  'Diego': 1,
#  'Diego.': 1,
#  'Director': 1,
#  'Disorder': 1,
#  'Dr.': 2,
#  'EST.': 1,
#  'Earl': 2,
#  'Eating': 1,
#  'Edwards': 2,
#  'Engineering': 1,
#  'FIFTY': 1,
#  'Friday': 1,
#  'GOD': 1,
#  'Good': 1,
#  'Got': 1,
#  'Great': 2,
#  'HATE': 1,
#  'HOW': 1,
#  'HUNDRED': 1,
#  'Healing': 1,
#  'High': 1,
#  'Highlight': 1,
#  'Hope': 1,
#  'Hope’s': 1,
#  'I...': 1,
#  'IT’S': 1,
#  'Iaido': 1,
#  'Implications': 1,
#  'Improved': 1,
#  'India': 1,
#  'Invite': 1,
#  'I’ll': 1,
#  'JUST': 1,
#  'Jacob': 1,
#  'Jolla': 1,
#  'Journal': 1,
#  'Jr.': 1,
#  'Jumping': 1,
#  'Just': 1,
#  'Kaye': 1,
#  'LIKE': 1,
#  'LMFAOOO': 1,
#  'Live': 1,
#  'Loa': 1,
#  'MAKE': 1,
#  'MIT': 1,
#  'MODELO': 1,
#  'MUCH': 1,
#  'MZmine-GNPS': 1,
#  'Madani': 1,
#  'Mark': 1,
#  'Mauna': 1,
#  'McManus': 1,
#  "Men's": 1,
#  'Michael': 1,
#  'Monday.': 1,
#  'Monthly': 2,
#  'More': 2,
#  'Neutrophil': 1,
#  'No.1': 1,
#  'Nobel': 1,
#  'Node:': 1,
#  'OHHHHH': 1,
#  'OMG!!': 1,
#  'One': 1,
#  'Orlando': 1,
#  'PAY': 1,
#  'Part': 1,
#  'Pines)': 1,
#  'Polo': 1,
#  'Pope': 1,
#  'Prior': 1,
#  'REINSTATED': 1,
#  'Research:': 1,
#  'SDSU': 1,
#  'San': 2,
#  'Sartorius': 1,
#  'Saturday': 1,
#  'School': 1,
#  'Second': 1,
#  'Sept': 1,
#  'Sept.': 1,
#  'September': 2,
#  'Setting': 1,
#  'Stats': 1,
#  "Summer's": 1,
#  'THE': 1,
#  'THEYRE': 1,
#  'TIME': 1,
#  'TODAY!!': 1,
#  'Thank': 2,
#  'The': 3,
#  'This': 4,
#  'Thoughts': 1,
#  'Tops': 1,
#  'Treatment': 1,
#  'Triton': 1,
#  'Tues': 1,
#  'Tuesday!': 1,
#  'Two': 1,
#  'UCSD': 18,
#  'UCSD!': 1,
#  'UCSD.': 2,
#  'UCSD’s': 1,
#  'USC': 1,
#  'University': 1,
#  'Very': 1,
#  'Virtual': 1,
#  'Waiting': 1,
#  'Walter': 1,
#  'Washington': 2,
#  'Water': 1,
#  'West': 1,
#  'Would': 1,
#  'YOU': 1,
#  'about': 3,
#  'accepted': 1,
#  'accommodates': 1,
#  'acres': 1,
#  'against': 1,
#  'ago': 1,
#  'all': 3,
#  'alums': 1,
#  'always': 1,
#  'and': 8,
#  'anniversary': 1,
#  'annual': 1,
#  'apartments': 1,
#  'are': 2,
#  'area.': 1,
#  'arthritis': 1,
#  'atmosphere': 1,
#  'back': 2,
#  'because': 1,
#  'become': 1,
#  'being': 1,
#  'believe': 2,
#  'best': 2,
#  'blog': 1,
#  'but': 1,
#  'campus': 1,
#  "can't": 1,
#  'can’t': 2,
#  'card': 1,
#  'case': 1,
#  'central': 1,
#  'chain-link': 1,
#  'chose': 1,
#  'classism': 1,
#  'clots': 1,
#  'club': 2,
#  'co-organized': 1,
#  'collaboration': 1,
#  'colleagues': 1,
#  'come': 1,
#  'coming': 1,
#  'commence': 1,
#  'committed': 1,
#  'contributions': 1,
#  'could': 1,
#  'courses': 2,
#  'cross': 1,
#  'daily': 1,
#  'data': 1,
#  'day': 1,
#  'deadly': 1,
#  'dear': 1,
#  'dedicated': 1,
#  'details': 1,
#  'different': 1,
#  'disappointed.': 1,
#  'discuss': 1,
#  'doesn’t': 1,
#  'down': 2,
#  'during': 2,
#  'easy': 1,
#  'eats': 1,
#  'engagement': 1,
#  'event': 1,
#  'everyone': 1,
#  'excited': 1,
#  'exciting': 1,
#  'expectations': 1,
#  'facility': 2,
#  'father': 1,
#  'feet': 1,
#  'fence': 1,
#  'find': 1,
#  'finishing': 1,
#  'first': 2,
#  'first-gen': 1,
#  'fom': 1,
#  'football': 1,
#  'for': 11,
#  'forward': 1,
#  'friends': 1,
#  'from': 6,
#  'future': 1,
#  'game': 1,
#  'giving': 1,
#  'go..if': 1,
#  'goes': 1,
#  'going': 2,
#  'good': 1,
#  'grad': 1,
#  'graphic:': 1,
#  'grateful': 1,
#  'great': 1,
#  'group': 1,
#  'groupings.': 1,
#  'guys!': 1,
#  'hangs': 1,
#  'has': 3,
#  'have': 5,
#  'healthier': 1,
#  'helping': 1,
#  'here’s': 1,
#  'his': 1,
#  'home': 2,
#  'host': 1,
#  'hosted': 1,
#  'hosting': 1,
#  'how': 1,
#  'http://dlvr.it/Qhr6Qp': 1,
#  'http://ow.ly/TKnC30lzFBs': 1,
#  'http://phdtraveler.blogspot.com': 1,
#  'http://www.goredlands.com/x/zopca': 1,
#  'http://www.ucsdtritons.com/ViewArticle.dbml?DB_OEM_ID=5800&ATCLID=211770300': 1,
#  'https://buff.ly/LGtoGE': 1,
#  'https://scripps.ucsd.edu/programs/keelingcurve/': 1,
#  'https://www.co2.earth/daily-co2': 1,
#  'https://www.facebook.com/JAMIESCOTTmobile/posts/2177799288905402': 1,
#  'https://www.instagram.com/p/BnRkQwEHJiu/?utm_source=ig_twitter_share&igshid=q4h7a4a4khwn': 1,
#  'idyllic': 1,
#  'inaugural': 1,
#  'includes': 1,
#  'increase': 1,
#  'initially': 1,
#  'interesting': 1,
#  'isn’t': 1,
#  'its': 3,
#  'join': 1,
#  'journal': 1,
#  'joy': 1,
#  'junior': 1,
#  'key': 1,
#  'know': 2,
#  'last': 1,
#  'later.': 1,
#  'leading': 1,
#  'like': 1,
#  'live': 1,
#  'lives.': 1,
#  'long': 1,
#  'longer': 1,
#  'lot': 1,
#  'love': 1,
#  'luck': 1,
#  'lungs': 2,
#  'lungs.': 1,
#  'made': 1,
#  'make': 2,
#  'making': 1,
#  'management': 1,
#  'manar': 1,
#  'mandate.': 1,
#  'many': 1,
#  'meme': 1,
#  'men': 1,
#  'million': 1,
#  'mis-judged': 1,
#  'mobility': 1,
#  'month': 2,
#  'more': 1,
#  'morning': 1,
#  'named': 1,
#  'nanosponges': 1,
#  'nation': 1,
#  'new': 4,
#  'next': 1,
#  'note': 1,
#  'now': 1,
#  'number': 1,
#  'observed': 1,
#  'offer': 1,
#  'one': 2,
#  'open': 1,
#  'opener': 1,
#  'opportunity': 2,
#  'our': 3,
#  'out': 1,
#  'over-ran': 1,
#  'pains': 1,
#  'paintings': 1,
#  'paper': 1,
#  'parking': 2,
#  'parts': 1,
#  'past': 2,
#  'patients': 1,
#  'per': 1,
#  'performed': 1,
#  'physically': 1,
#  'pizza': 1,
#  'posted': 1,
#  'privilege': 1,
#  'procedures': 1,
#  'process': 1,
#  'program': 1,
#  'promote': 1,
#  'proposal': 1,
#  'proteins': 1,
#  'public': 2,
#  'published': 1,
#  'quiz': 1,
#  'ranked': 1,
#  'recently': 1,
#  'rejected': 2,
#  'remind': 1,
#  'remove': 1,
#  'research': 1,
#  'returned.': 1,
#  'rheumatoid': 1,
#  'roughly': 1,
#  'same': 2,
#  'say': 1,
#  'saying': 1,
#  'school': 2,
#  'school.': 1,
#  'school...': 1,
#  'season.': 2,
#  'second': 1,
#  'seem': 1,
#  'sepsis': 1,
#  'series': 1,
#  'service.': 1,
#  'should': 1,
#  'shoutout': 1,
#  'soak': 1,
#  'soccer': 1,
#  'social': 1,
#  'space': 1,
#  'start': 1,
#  'story.': 1,
#  'straight': 1,
#  'student': 2,
#  'students': 2,
#  'submitted.': 1,
#  'summer': 1,
#  'supporters': 1,
#  'sure': 1,
#  'symposium': 1,
#  'take': 2,
#  'taking': 2,
#  'teachers.': 1,
#  'team': 1,
#  'teams': 1,
#  'thanks': 1,
#  'that': 8,
#  'the': 34,
#  'they': 1,
#  'thinking': 1,
#  'third': 1,
#  'this': 5,
#  'thromboendarterectomy': 1,
#  'time': 1,
#  'time.': 1,
#  'tinge': 1,
#  "today's": 1,
#  'too!': 1,
#  'tradition': 1,
#  'training': 1,
#  'trauma': 2,
#  'travel': 1,
#  'travels': 1,
#  'tumblr': 1,
#  'tutorial': 1,
#  'tweets!👌🏽Special': 1,
#  'types': 1,
#  'ucsd?': 1,
#  'university': 2,
#  'up.': 1,
#  'updates': 1,
#  'view': 1,
#  'waitlisted': 1,
#  'was': 2,
#  'week': 1,
#  'weekend': 1,
#  'weird': 1,
#  'were': 2,
#  'which': 1,
#  'while': 1,
#  'who': 2,
#  'will': 3,
#  'winding': 1,
#  'wins': 1,
#  'with': 2,
#  'women': 1,
#  "women's": 1,
#  'work': 1,
#  'ya’ll': 1,
#  'year?': 1,
#  'you': 5,
#  '“Anorexia': 1,
#  '😂😂🦋': 1}

# %% [markdown]
# # 2.b. Tokenize again (with NLTK this time)
#
# Why is UCSD only in 18?
#
# Because of `@UCSD` and similar.
#
# Tokenizing (like most things) is harder than it looks at first!
#
# Generally, a good solution is to use a tool built for the job rather than rolling your own.  In this case, we will use the Python package Natural Language ToolKit, NLTK.
#
# You may need to install NLTK and also download an English language corpus.  If so, do this in the terminal:
#
# ```
# pip install --user nltk
# ```
#
# Then in Jupyter run this once:
# ```
# import nltk
# nltk.download('punkt')
# ```
#
# Run the code below to use NLTK's tokenizer, and then repeat the process of removing short words and counting.

# %%
import nltk
nltk.download('punkt')
from nltk import tokenize
# Out:
# [nltk_data] Downloading package punkt to /home/zhg061/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
allText = string # pass in a string consisting of all tweets

wordList = tokenize.word_tokenize(allText)
len(wordList)
# Out:
# 1050

# %%
wordList
# Out:
# ['UCSD',
#  'ranked',
#  '7th',
#  'best',
#  'school',
#  'in',
#  'US',
#  'by',
#  'Washington',
#  'Monthly',
#  'it',
#  'physically',
#  'pains',
#  'me',
#  'that',
#  'UCSD',
#  'doesn',
#  '’',
#  't',
#  'have',
#  'a',
#  'football',
#  'team',
#  'A',
#  'card',
#  'mis-judged',
#  'a',
#  'parking',
#  'space',
#  'and',
#  'over-ran',
#  'a',
#  'parking',
#  'lot',
#  'in',
#  'the',
#  'process',
#  'taking',
#  'out',
#  'about',
#  'about',
#  '40',
#  'to',
#  '50',
#  'feet',
#  'of',
#  'chain-link',
#  'fence',
#  'this',
#  'morning',
#  'at',
#  'the',
#  'Nobel',
#  'apartments',
#  'in',
#  'the',
#  'UCSD',
#  'area',
#  '.',
#  'Around',
#  '9:10',
#  'AM',
#  'I',
#  '...',
#  'https',
#  ':',
#  '//www.facebook.com/JAMIESCOTTmobile/posts/2177799288905402',
#  '…',
#  'Almost',
#  '50',
#  '%',
#  'increase',
#  'in',
#  '#',
#  'PedsICU',
#  'engagement',
#  'from',
#  'last',
#  'week',
#  '&',
#  '>',
#  '1000',
#  'tweets',
#  '!',
#  '👌🏽Special',
#  'shoutout',
#  'to',
#  '@',
#  'DrKanaris',
#  'for',
#  'the',
#  'new',
#  'Friday',
#  '#',
#  'PedsICU',
#  'quiz',
#  'tradition',
#  '&',
#  '@',
#  'UCSD_PICU',
#  'for',
#  'the',
#  'great',
#  '#',
#  'meded',
#  '!',
#  '@',
#  'healthhashtags',
#  '#',
#  'medtwitter',
#  'here',
#  '’',
#  's',
#  'a',
#  'tinge',
#  'of',
#  'classism',
#  'in',
#  'saying',
#  'SDSU',
#  'should',
#  'make',
#  'do',
#  'with',
#  'its',
#  '283',
#  'acres',
#  'while',
#  'UCSD',
#  'accommodates',
#  'roughly',
#  'the',
#  'same',
#  'number',
#  'of',
#  'students',
#  'on',
#  'its',
#  'idyllic',
#  '2141-acre',
#  'campus',
#  'This',
#  'past',
#  'weekend',
#  'we',
#  'observed',
#  'the',
#  '25th',
#  'anniversary',
#  'of',
#  'the',
#  'UCSD',
#  'Iaido',
#  'club',
#  'in',
#  'San',
#  'Diego',
#  '.',
#  'The',
#  'training',
#  'was',
#  'dedicated',
#  'to',
#  'our',
#  'past',
#  'teachers',
#  '.',
#  'I',
#  'HATE',
#  'UCSD',
#  'SO',
#  'MUCH',
#  'THEYRE',
#  'SO',
#  'ANNOYING',
#  'OHHHHH',
#  'MY',
#  'GOD',
#  'LMFAOOO',
#  'UCSD',
#  'JUST',
#  'CALLED',
#  'ME',
#  'ASKING',
#  'IF',
#  'I',
#  'COULD',
#  'MAKE',
#  'A',
#  '$',
#  '250',
#  '(',
#  'T',
#  'W',
#  'O',
#  'HUNDRED',
#  'FIFTY',
#  'DOLLAR',
#  ')',
#  'DONATION',
#  'LIKE',
#  'BITCH',
#  'HOW',
#  'BOUT',
#  'YOU',
#  'PAY',
#  'ME',
#  'I',
#  'chose',
#  'UCSD',
#  'because',
#  'it',
#  'has',
#  'the',
#  'best',
#  'fb',
#  'meme',
#  'group',
#  'High',
#  'key',
#  'excited',
#  'to',
#  'be',
#  'going',
#  'back',
#  'to',
#  'UCSD',
#  '💙💛',
#  'OMG',
#  '!',
#  '!',
#  'Got',
#  'THE',
#  'CALL',
#  'for',
#  'lungs',
#  'at',
#  '5:30am',
#  '!',
#  'Waiting',
#  'at',
#  'UCSD',
#  'to',
#  'make',
#  'sure',
#  'they',
#  'are',
#  'a',
#  'go..if',
#  'so',
#  'I',
#  'could',
#  'have',
#  'new',
#  'lungs',
#  'TODAY',
#  '!',
#  '!',
#  '😂😂🦋',
#  '#',
#  'cysticfibrosis',
#  '#',
#  'trandplanttime',
#  'Did',
#  'ya',
#  '’',
#  'll',
#  'know',
#  'I',
#  'was',
#  'initially',
#  'waitlisted',
#  'at',
#  'MIT',
#  'and',
#  'straight',
#  'up',
#  'rejected',
#  'from',
#  'UCSD',
#  'for',
#  'grad',
#  'school',
#  '.',
#  'Just',
#  'in',
#  'case',
#  'you',
#  'were',
#  'thinking',
#  'about',
#  'giving',
#  'up',
#  '.',
#  'UCSD',
#  'women',
#  "'s",
#  'soccer',
#  'wins',
#  'home',
#  'opener',
#  'as',
#  'McManus',
#  'eats',
#  'pizza',
#  'http',
#  ':',
#  '//dlvr.it/Qhr6Qp',
#  'i',
#  'can',
#  '’',
#  't',
#  'believe',
#  'that',
#  'in',
#  'a',
#  'month',
#  'summer',
#  'manar',
#  'and',
#  'i',
#  'will',
#  'all',
#  'being',
#  'going',
#  'to',
#  'the',
#  'same',
#  'school',
#  '...',
#  'ucsd',
#  '?',
#  'more',
#  'like',
#  'tumblr',
#  'university',
#  '@',
#  'UCSanDiego',
#  'named',
#  'No.1',
#  'public',
#  'university',
#  'in',
#  'the',
#  'nation',
#  'by',
#  'Washington',
#  'Monthly',
#  'for',
#  'its',
#  'contributions',
#  'to',
#  'social',
#  'mobility',
#  'research',
#  'and',
#  'public',
#  'service',
#  '.',
#  '@',
#  'washmonthly',
#  '#',
#  'ucsd',
#  '#',
#  'TritonPride',
#  'http',
#  ':',
#  '//ow.ly/TKnC30lzFBs',
#  'USC',
#  'rejected',
#  'me',
#  'and',
#  'UCSD',
#  'accepted',
#  'me',
#  'so',
#  'disappointed',
#  '.',
#  'Summer',
#  "'s",
#  'winding',
#  'down',
#  '...',
#  'how',
#  'many',
#  'new',
#  'UCSD',
#  'Bioengineering',
#  'students',
#  'become',
#  'alums',
#  'this',
#  'coming',
#  'year',
#  '?',
#  'Good',
#  'luck',
#  'to',
#  'you',
#  'guys',
#  '!',
#  'I',
#  'can',
#  '’',
#  't',
#  'seem',
#  'to',
#  'find',
#  'a',
#  'good',
#  'time',
#  'to',
#  'remind',
#  'everyone',
#  'that',
#  'the',
#  'inaugural',
#  '#',
#  'PedsICU',
#  'Journal',
#  'Club',
#  'will',
#  'commence',
#  'on',
#  'Sept.',
#  '18',
#  'at',
#  '7',
#  'central',
#  'time',
#  '.',
#  '10',
#  'pm',
#  'on',
#  'a',
#  'Saturday',
#  'isn',
#  '’',
#  't',
#  'it',
#  'but',
#  'I',
#  '’',
#  'll',
#  'RT',
#  'later',
#  '.',
#  'UCSD',
#  'REINSTATED',
#  'ME',
#  'IT',
#  '’',
#  'S',
#  'MODELO',
#  'TIME',
#  'Great',
#  'opportunity',
#  'to',
#  'take',
#  'the',
#  'ATOM',
#  '&',
#  'ASSET',
#  'trauma',
#  'courses',
#  'at',
#  'the',
#  'the',
#  '@',
#  'CFS_UCSD',
#  'facility',
#  'during',
#  '#',
#  'AAST2018',
#  '#',
#  'wtc2018',
#  'at',
#  '@',
#  'UCSDsurgery',
#  'Jumping',
#  'for',
#  'joy',
#  'on',
#  'this',
#  'easy',
#  'Monday',
#  '.',
#  '#',
#  'laborday',
#  '#',
#  'holiday',
#  '#',
#  'sandiego',
#  '#',
#  'california',
#  '@',
#  'UCSD',
#  '-',
#  'University',
#  'of',
#  'California',
#  'San',
#  'Diego',
#  'https',
#  ':',
#  '//www.instagram.com/p/BnRkQwEHJiu/',
#  '?',
#  'utm_source=ig_twitter_share',
#  '&',
#  'igshid=q4h7a4a4khwn',
#  '…',
#  'This',
#  'is',
#  'a',
#  'weird',
#  'story',
#  '.',
#  'Of',
#  'note',
#  'UCSD',
#  '’',
#  's',
#  'Athletic',
#  'Director',
#  'is',
#  'Earl',
#  'Edwards',
#  'father',
#  'of',
#  'Orlando',
#  'City',
#  'GK',
#  'Earl',
#  'Edwards',
#  'Jr.',
#  'Second',
#  '#',
#  'NASPA',
#  'proposal',
#  'submitted',
#  '.',
#  '😅',
#  'This',
#  'one',
#  'in',
#  'collaboration',
#  'with',
#  'my',
#  'dear',
#  'friends',
#  'and',
#  'colleagues',
#  'who',
#  'co-organized',
#  'the',
#  'UC',
#  'first-gen',
#  'symposium',
#  'hosted',
#  '@',
#  'UCSD',
#  '.',
#  '@',
#  'AleceAnderson',
#  '@',
#  'ucfirstgen',
#  '@',
#  'UCdiverse',
#  '#',
#  'teamworkmakesthedreamwork',
#  'Very',
#  'interesting',
#  'work',
#  'from',
#  'UCSD',
#  'Neutrophil',
#  'nanosponges',
#  'soak',
#  'up',
#  'proteins',
#  'that',
#  'promote',
#  'rheumatoid',
#  'arthritis',
#  'Part',
#  'one',
#  'of',
#  'our',
#  'series',
#  'by',
#  '@',
#  'UCSD_EDC',
#  "'s",
#  'Dr.',
#  'Walter',
#  'Kaye',
#  'Anorexia',
#  'Current',
#  '&',
#  'Prior',
#  'Research',
#  ':',
#  'Implications',
#  'for',
#  'Improved',
#  'Treatment',
#  'fom',
#  'Eating',
#  'Disorder',
#  'Hope',
#  '’',
#  's',
#  'Virtual',
#  'Conference',
#  '“',
#  'Anorexia',
#  'Hope',
#  '&',
#  'Healing',
#  'in',
#  '2018',
#  '”',
#  'U',
#  'of',
#  'R',
#  'Men',
#  "'s",
#  'Water',
#  'Polo',
#  'Tops',
#  'Chapman',
#  'to',
#  'Highlight',
#  'Day',
#  'Two',
#  'of',
#  'UCSD',
#  'Triton',
#  'Invite',
#  'http',
#  ':',
#  '//www.goredlands.com/x/zopca',
#  '#',
#  'URDawgs',
#  '#',
#  'TimeToShine',
#  '📈',
#  '405.60',
#  'parts',
#  'per',
#  'million',
#  '(',
#  'ppm',
#  ')',
#  '#',
#  'CO2',
#  'in',
#  'the',
#  'atmosphere',
#  'on',
#  'September',
#  '2',
#  '2018',
#  '🔗',
#  '#',
#  'Scripps',
#  '#',
#  'UCSD',
#  'Mauna',
#  'Loa',
#  'data',
#  '&',
#  'graphic',
#  ':',
#  'https',
#  ':',
#  '//scripps.ucsd.edu/programs/keelingcurve/',
#  '…',
#  '👥',
#  'Also',
#  'view',
#  'daily',
#  'CO2',
#  'updates',
#  'at',
#  'https',
#  ':',
#  '//www.co2.earth/daily-co2',
#  'Thank',
#  'you',
#  'to',
#  'all',
#  'the',
#  'teams',
#  '&',
#  'supporters',
#  'who',
#  'made',
#  'it',
#  'down',
#  'to',
#  'La',
#  'Jolla',
#  'for',
#  'the',
#  'annual',
#  '#',
#  'TritonInvite',
#  '.',
#  'It',
#  'is',
#  'always',
#  'an',
#  'exciting',
#  'event',
#  '&',
#  'we',
#  'are',
#  'grateful',
#  'to',
#  'host',
#  'the',
#  'start',
#  'of',
#  'the',
#  '2018',
#  'season',
#  '.',
#  'The',
#  'next',
#  'home',
#  'game',
#  'for',
#  '@',
#  'UCSDTritonsMWP',
#  'will',
#  'be',
#  'September',
#  '19th',
#  'at',
#  '6pm',
#  'against',
#  '@',
#  'LBSUWaterPolo',
#  '!',
#  'I',
#  'ca',
#  "n't",
#  'believe',
#  'I',
#  'have',
#  'the',
#  'privilege',
#  'to',
#  'say',
#  'that',
#  'I',
#  'am',
#  'a',
#  'student',
#  'in',
#  'the',
#  'Jacob',
#  'Sartorius',
#  'School',
#  'of',
#  'Engineering',
#  'at',
#  'UCSD',
#  '.',
#  '🤧',
#  'Congrats',
#  'to',
#  'junior',
#  'forward',
#  'Brandon',
#  'Angel',
#  'on',
#  'his',
#  'offer',
#  'from',
#  'future',
#  'Big',
#  'West',
#  'school',
#  'UCSD',
#  '!',
#  '#',
#  'GoFalcons',
#  'One',
#  'of',
#  'my',
#  'first',
#  '#',
#  'retina',
#  'paintings',
#  'that',
#  'now',
#  'hangs',
#  'at',
#  '#',
#  'UCSD',
#  '.',
#  'Commissioned',
#  'in',
#  '2012',
#  '.',
#  '#',
#  'goldleaf',
#  '#',
#  'art',
#  'https',
#  ':',
#  '//buff.ly/LGtoGE',
#  'More',
#  'on',
#  'the',
#  'men',
#  'finishing',
#  'second',
#  'and',
#  'the',
#  'women',
#  'taking',
#  'third',
#  'at',
#  'today',
#  "'s",
#  'Mark',
#  'Covert',
#  'Classic',
#  'to',
#  'open',
#  'the',
#  'season',
#  '.',
#  'http',
#  ':',
#  '//www.ucsdtritons.com/ViewArticle.dbml',
#  '?',
#  'DB_OEM_ID=5800',
#  '&',
#  'ATCLID=211770300',
#  '…',
#  '#',
#  'GoTritons',
#  '🔱',
#  '#',
#  'PHMFellowsJC',
#  'is',
#  'hosting',
#  'our',
#  'first',
#  'journal',
#  'club',
#  'this',
#  'month',
#  'too',
#  '!',
#  'Tues',
#  'Sept',
#  '11',
#  '9',
#  'pm',
#  'EST',
#  '.',
#  'Would',
#  'love',
#  'to',
#  'have',
#  '#',
#  'PedsICU',
#  'join',
#  'us',
#  'to',
#  'discuss',
#  'the',
#  'recently',
#  'published',
#  '@',
#  'JAMA_current',
#  'paper',
#  'on',
#  'the',
#  'NY',
#  'sepsis',
#  'mandate',
#  '.',
#  'More',
#  'details',
#  'to',
#  'come',
#  'this',
#  'Tuesday',
#  '!',
#  'Great',
#  'opportunity',
#  'to',
#  'take',
#  'the',
#  'ATOM',
#  '&',
#  'ASSET',
#  'trauma',
#  'courses',
#  'at',
#  'the',
#  'the',
#  '@',
#  'CFS_UCSD',
#  'facility',
#  'during',
#  '#',
#  'AAST2018',
#  '#',
#  'wtc2018',
#  'at',
#  '@',
#  'UCSDsurgery',
#  'Live',
#  'from',
#  'India',
#  '-',
#  'my',
#  'travel',
#  'blog',
#  'has',
#  'returned',
#  '.',
#  'This',
#  'goes',
#  'back',
#  'to',
#  '2005',
#  'and',
#  'includes',
#  'all',
#  'my',
#  'China',
#  'travels',
#  'that',
#  'were',
#  'long',
#  'ago',
#  'cross',
#  'posted',
#  'to',
#  'the',
#  'Node',
#  ':',
#  'http',
#  ':',
#  '//phdtraveler.blogspot.com',
#  '2019',
#  'G',
#  'Bryce',
#  'Pope',
#  '(',
#  'Torrey',
#  'Pines',
#  ')',
#  'has',
#  'committed',
#  'to',
#  'UCSD',
#  '.',
#  '#',
#  'gpnation',
#  'Did',
#  'you',
#  'know',
#  'that',
#  '@',
#  'UCSDHealth',
#  '#',
#  'surgeons',
#  'have',
#  'performed',
#  '>',
#  '3900',
#  '#',
#  'pulmonary',
#  'thromboendarterectomy',
#  'procedures',
#  'which',
#  'remove',
#  'deadly',
#  'clots',
#  'from',
#  'the',
#  'lungs',
#  '.',
#  'Thank',
#  'you',
#  'Dr.',
#  'Michael',
#  'Madani',
#  'for',
#  'leading',
#  'the',
#  ...]

# %% [markdown]
# # 3.b. Count (again)

# %%
# Remove short words
new_long_words = []
for i in range(len(wordList)):
    if len(wordList[i]) >= 3:
        new_long_words.append(wordList[i])
new_long_words
# Out:
# ['UCSD',
#  'ranked',
#  '7th',
#  'best',
#  'school',
#  'Washington',
#  'Monthly',
#  'physically',
#  'pains',
#  'that',
#  'UCSD',
#  'doesn',
#  'have',
#  'football',
#  'team',
#  'card',
#  'mis-judged',
#  'parking',
#  'space',
#  'and',
#  'over-ran',
#  'parking',
#  'lot',
#  'the',
#  'process',
#  'taking',
#  'out',
#  'about',
#  'about',
#  'feet',
#  'chain-link',
#  'fence',
#  'this',
#  'morning',
#  'the',
#  'Nobel',
#  'apartments',
#  'the',
#  'UCSD',
#  'area',
#  'Around',
#  '9:10',
#  '...',
#  'https',
#  '//www.facebook.com/JAMIESCOTTmobile/posts/2177799288905402',
#  'Almost',
#  'increase',
#  'PedsICU',
#  'engagement',
#  'from',
#  'last',
#  'week',
#  '1000',
#  'tweets',
#  '👌🏽Special',
#  'shoutout',
#  'DrKanaris',
#  'for',
#  'the',
#  'new',
#  'Friday',
#  'PedsICU',
#  'quiz',
#  'tradition',
#  'UCSD_PICU',
#  'for',
#  'the',
#  'great',
#  'meded',
#  'healthhashtags',
#  'medtwitter',
#  'here',
#  'tinge',
#  'classism',
#  'saying',
#  'SDSU',
#  'should',
#  'make',
#  'with',
#  'its',
#  '283',
#  'acres',
#  'while',
#  'UCSD',
#  'accommodates',
#  'roughly',
#  'the',
#  'same',
#  'number',
#  'students',
#  'its',
#  'idyllic',
#  '2141-acre',
#  'campus',
#  'This',
#  'past',
#  'weekend',
#  'observed',
#  'the',
#  '25th',
#  'anniversary',
#  'the',
#  'UCSD',
#  'Iaido',
#  'club',
#  'San',
#  'Diego',
#  'The',
#  'training',
#  'was',
#  'dedicated',
#  'our',
#  'past',
#  'teachers',
#  'HATE',
#  'UCSD',
#  'MUCH',
#  'THEYRE',
#  'ANNOYING',
#  'OHHHHH',
#  'GOD',
#  'LMFAOOO',
#  'UCSD',
#  'JUST',
#  'CALLED',
#  'ASKING',
#  'COULD',
#  'MAKE',
#  '250',
#  'HUNDRED',
#  'FIFTY',
#  'DOLLAR',
#  'DONATION',
#  'LIKE',
#  'BITCH',
#  'HOW',
#  'BOUT',
#  'YOU',
#  'PAY',
#  'chose',
#  'UCSD',
#  'because',
#  'has',
#  'the',
#  'best',
#  'meme',
#  'group',
#  'High',
#  'key',
#  'excited',
#  'going',
#  'back',
#  'UCSD',
#  'OMG',
#  'Got',
#  'THE',
#  'CALL',
#  'for',
#  'lungs',
#  '5:30am',
#  'Waiting',
#  'UCSD',
#  'make',
#  'sure',
#  'they',
#  'are',
#  'go..if',
#  'could',
#  'have',
#  'new',
#  'lungs',
#  'TODAY',
#  '😂😂🦋',
#  'cysticfibrosis',
#  'trandplanttime',
#  'Did',
#  'know',
#  'was',
#  'initially',
#  'waitlisted',
#  'MIT',
#  'and',
#  'straight',
#  'rejected',
#  'from',
#  'UCSD',
#  'for',
#  'grad',
#  'school',
#  'Just',
#  'case',
#  'you',
#  'were',
#  'thinking',
#  'about',
#  'giving',
#  'UCSD',
#  'women',
#  'soccer',
#  'wins',
#  'home',
#  'opener',
#  'McManus',
#  'eats',
#  'pizza',
#  'http',
#  '//dlvr.it/Qhr6Qp',
#  'can',
#  'believe',
#  'that',
#  'month',
#  'summer',
#  'manar',
#  'and',
#  'will',
#  'all',
#  'being',
#  'going',
#  'the',
#  'same',
#  'school',
#  '...',
#  'ucsd',
#  'more',
#  'like',
#  'tumblr',
#  'university',
#  'UCSanDiego',
#  'named',
#  'No.1',
#  'public',
#  'university',
#  'the',
#  'nation',
#  'Washington',
#  'Monthly',
#  'for',
#  'its',
#  'contributions',
#  'social',
#  'mobility',
#  'research',
#  'and',
#  'public',
#  'service',
#  'washmonthly',
#  'ucsd',
#  'TritonPride',
#  'http',
#  '//ow.ly/TKnC30lzFBs',
#  'USC',
#  'rejected',
#  'and',
#  'UCSD',
#  'accepted',
#  'disappointed',
#  'Summer',
#  'winding',
#  'down',
#  '...',
#  'how',
#  'many',
#  'new',
#  'UCSD',
#  'Bioengineering',
#  'students',
#  'become',
#  'alums',
#  'this',
#  'coming',
#  'year',
#  'Good',
#  'luck',
#  'you',
#  'guys',
#  'can',
#  'seem',
#  'find',
#  'good',
#  'time',
#  'remind',
#  'everyone',
#  'that',
#  'the',
#  'inaugural',
#  'PedsICU',
#  'Journal',
#  'Club',
#  'will',
#  'commence',
#  'Sept.',
#  'central',
#  'time',
#  'Saturday',
#  'isn',
#  'but',
#  'later',
#  'UCSD',
#  'REINSTATED',
#  'MODELO',
#  'TIME',
#  'Great',
#  'opportunity',
#  'take',
#  'the',
#  'ATOM',
#  'ASSET',
#  'trauma',
#  'courses',
#  'the',
#  'the',
#  'CFS_UCSD',
#  'facility',
#  'during',
#  'AAST2018',
#  'wtc2018',
#  'UCSDsurgery',
#  'Jumping',
#  'for',
#  'joy',
#  'this',
#  'easy',
#  'Monday',
#  'laborday',
#  'holiday',
#  'sandiego',
#  'california',
#  'UCSD',
#  'University',
#  'California',
#  'San',
#  'Diego',
#  'https',
#  '//www.instagram.com/p/BnRkQwEHJiu/',
#  'utm_source=ig_twitter_share',
#  'igshid=q4h7a4a4khwn',
#  'This',
#  'weird',
#  'story',
#  'note',
#  'UCSD',
#  'Athletic',
#  'Director',
#  'Earl',
#  'Edwards',
#  'father',
#  'Orlando',
#  'City',
#  'Earl',
#  'Edwards',
#  'Jr.',
#  'Second',
#  'NASPA',
#  'proposal',
#  'submitted',
#  'This',
#  'one',
#  'collaboration',
#  'with',
#  'dear',
#  'friends',
#  'and',
#  'colleagues',
#  'who',
#  'co-organized',
#  'the',
#  'first-gen',
#  'symposium',
#  'hosted',
#  'UCSD',
#  'AleceAnderson',
#  'ucfirstgen',
#  'UCdiverse',
#  'teamworkmakesthedreamwork',
#  'Very',
#  'interesting',
#  'work',
#  'from',
#  'UCSD',
#  'Neutrophil',
#  'nanosponges',
#  'soak',
#  'proteins',
#  'that',
#  'promote',
#  'rheumatoid',
#  'arthritis',
#  'Part',
#  'one',
#  'our',
#  'series',
#  'UCSD_EDC',
#  'Dr.',
#  'Walter',
#  'Kaye',
#  'Anorexia',
#  'Current',
#  'Prior',
#  'Research',
#  'Implications',
#  'for',
#  'Improved',
#  'Treatment',
#  'fom',
#  'Eating',
#  'Disorder',
#  'Hope',
#  'Virtual',
#  'Conference',
#  'Anorexia',
#  'Hope',
#  'Healing',
#  '2018',
#  'Men',
#  'Water',
#  'Polo',
#  'Tops',
#  'Chapman',
#  'Highlight',
#  'Day',
#  'Two',
#  'UCSD',
#  'Triton',
#  'Invite',
#  'http',
#  '//www.goredlands.com/x/zopca',
#  'URDawgs',
#  'TimeToShine',
#  '405.60',
#  'parts',
#  'per',
#  'million',
#  'ppm',
#  'CO2',
#  'the',
#  'atmosphere',
#  'September',
#  '2018',
#  'Scripps',
#  'UCSD',
#  'Mauna',
#  'Loa',
#  'data',
#  'graphic',
#  'https',
#  '//scripps.ucsd.edu/programs/keelingcurve/',
#  'Also',
#  'view',
#  'daily',
#  'CO2',
#  'updates',
#  'https',
#  '//www.co2.earth/daily-co2',
#  'Thank',
#  'you',
#  'all',
#  'the',
#  'teams',
#  'supporters',
#  'who',
#  'made',
#  'down',
#  'Jolla',
#  'for',
#  'the',
#  'annual',
#  'TritonInvite',
#  'always',
#  'exciting',
#  'event',
#  'are',
#  'grateful',
#  'host',
#  'the',
#  'start',
#  'the',
#  '2018',
#  'season',
#  'The',
#  'next',
#  'home',
#  'game',
#  'for',
#  'UCSDTritonsMWP',
#  'will',
#  'September',
#  '19th',
#  '6pm',
#  'against',
#  'LBSUWaterPolo',
#  "n't",
#  'believe',
#  'have',
#  'the',
#  'privilege',
#  'say',
#  'that',
#  'student',
#  'the',
#  'Jacob',
#  'Sartorius',
#  'School',
#  'Engineering',
#  'UCSD',
#  'Congrats',
#  'junior',
#  'forward',
#  'Brandon',
#  'Angel',
#  'his',
#  'offer',
#  'from',
#  'future',
#  'Big',
#  'West',
#  'school',
#  'UCSD',
#  'GoFalcons',
#  'One',
#  'first',
#  'retina',
#  'paintings',
#  'that',
#  'now',
#  'hangs',
#  'UCSD',
#  'Commissioned',
#  '2012',
#  'goldleaf',
#  'art',
#  'https',
#  '//buff.ly/LGtoGE',
#  'More',
#  'the',
#  'men',
#  'finishing',
#  'second',
#  'and',
#  'the',
#  'women',
#  'taking',
#  'third',
#  'today',
#  'Mark',
#  'Covert',
#  'Classic',
#  'open',
#  'the',
#  'season',
#  'http',
#  '//www.ucsdtritons.com/ViewArticle.dbml',
#  'DB_OEM_ID=5800',
#  'ATCLID=211770300',
#  'GoTritons',
#  'PHMFellowsJC',
#  'hosting',
#  'our',
#  'first',
#  'journal',
#  'club',
#  'this',
#  'month',
#  'too',
#  'Tues',
#  'Sept',
#  'EST',
#  'Would',
#  'love',
#  'have',
#  'PedsICU',
#  'join',
#  'discuss',
#  'the',
#  'recently',
#  'published',
#  'JAMA_current',
#  'paper',
#  'the',
#  'sepsis',
#  'mandate',
#  'More',
#  'details',
#  'come',
#  'this',
#  'Tuesday',
#  'Great',
#  'opportunity',
#  'take',
#  'the',
#  'ATOM',
#  'ASSET',
#  'trauma',
#  'courses',
#  'the',
#  'the',
#  'CFS_UCSD',
#  'facility',
#  'during',
#  'AAST2018',
#  'wtc2018',
#  'UCSDsurgery',
#  'Live',
#  'from',
#  'India',
#  'travel',
#  'blog',
#  'has',
#  'returned',
#  'This',
#  'goes',
#  'back',
#  '2005',
#  'and',
#  'includes',
#  'all',
#  'China',
#  'travels',
#  'that',
#  'were',
#  'long',
#  'ago',
#  'cross',
#  'posted',
#  'the',
#  'Node',
#  'http',
#  '//phdtraveler.blogspot.com',
#  '2019',
#  'Bryce',
#  'Pope',
#  'Torrey',
#  'Pines',
#  'has',
#  'committed',
#  'UCSD',
#  'gpnation',
#  'Did',
#  'you',
#  'know',
#  'that',
#  'UCSDHealth',
#  'surgeons',
#  'have',
#  'performed',
#  '3900',
#  'pulmonary',
#  'thromboendarterectomy',
#  'procedures',
#  'which',
#  'remove',
#  'deadly',
#  'clots',
#  'from',
#  'the',
#  'lungs',
#  'Thank',
#  'you',
#  'Dr.',
#  'Michael',
#  'Madani',
#  'for',
#  'leading',
#  'the',
#  'program',
#  'helping',
#  'patients',
#  'live',
#  'longer',
#  'healthier',
#  'lives',
#  'STS_CTsurgery',
#  'annalsthorsurg',
#  'The',
#  'new',
#  'MZmine-GNPS',
#  'tutorial',
#  'making',
#  'day',
#  'thanks',
#  'GNPS_UCSD',
#  'RealTimeChem',
#  'chemtwitter',
#  'Stats',
#  '101',
#  'Deep',
#  'Thoughts',
#  'pedsICU',
#  'Classroom',
#  'management',
#  'UHS_UCSD',
#  'Setting',
#  'expectations',
#  'for',
#  'different',
#  'types',
#  'student',
#  'groupings']

# %%
# Count
len(new_long_words)
# Out:
# 697

# %% [markdown]
# # Sentiment with NLTK
#
# What is sentiment?  Why do we care?
#
# Will need to run once:
# ```
# nltk.download('vader_lexicon')
# ```

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/zhg061/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sid = SentimentIntensityAnalyzer()
sid.polarity_scores("Good test!")
# Out:
# {'compound': 0.4926, 'neg': 0.0, 'neu': 0.239, 'pos': 0.761}

# %%
tweets = Table.read_table('data/UCSD tweets.csv')
tweetList = tweets.column('text')

# %%
tweetSentiments = []
for tweet in tweetList:
    tweetSentiment = sid.polarity_scores(tweet)
    tweetSentiment['text'] = tweet
    tweetSentiments.append(tweetSentiment)
    
tweetSentiments
# Out:
# [{'compound': 0.6369,
#   'neg': 0.0,
#   'neu': 0.682,
#   'pos': 0.318,
#   'text': 'UCSD ranked 7th best school in US by Washington Monthly '},
#  {'compound': -0.4215,
#   'neg': 0.237,
#   'neu': 0.763,
#   'pos': 0.0,
#   'text': 'it physically pains me that UCSD doesn’t have a football team'},
#  {'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'text': 'A card mis-judged a parking space and over-ran a parking lot in the process taking out about about 40 to 50 feet of chain-link fence this morning at the Nobel apartments in the UCSD area.  Around 9:10 AM I... https://www.facebook.com/JAMIESCOTTmobile/posts/2177799288905402 …'},
#  {'compound': 0.8659,
#   'neg': 0.0,
#   'neu': 0.72,
#   'pos': 0.28,
#   'text': 'Almost 50% increase in #PedsICU engagement from last week & >1000 tweets!👌🏽Special shoutout to @DrKanaris for the new Friday #PedsICU quiz tradition & @UCSD_PICU for the great #meded! @healthhashtags #medtwitter'},
#  {'compound': 0.0772,
#   'neg': 0.0,
#   'neu': 0.954,
#   'pos': 0.046,
#   'text': 'here’s a tinge of classism in saying SDSU should make do with its 283 acres while UCSD accommodates roughly the same number of students on its idyllic 2141-acre campus'},
#  {'compound': 0.4588,
#   'neg': 0.0,
#   'neu': 0.885,
#   'pos': 0.115,
#   'text': 'This past weekend we observed the 25th anniversary of the UCSD Iaido club in San Diego. The training was dedicated to our past teachers. '},
#  {'compound': -0.6801,
#   'neg': 0.424,
#   'neu': 0.443,
#   'pos': 0.133,
#   'text': 'I HATE UCSD SO MUCH THEYRE SO ANNOYING OHHHHH MY GOD'},
#  {'compound': -0.5319,
#   'neg': 0.231,
#   'neu': 0.657,
#   'pos': 0.112,
#   'text': 'LMFAOOO UCSD JUST CALLED ME ASKING IF I COULD MAKE A $250 (T W O HUNDRED FIFTY DOLLAR) DONATION LIKE BITCH HOW BOUT YOU PAY ME'},
#  {'compound': 0.6369,
#   'neg': 0.0,
#   'neu': 0.682,
#   'pos': 0.318,
#   'text': 'I chose UCSD because it has the best fb meme group'},
#  {'compound': 0.34,
#   'neg': 0.0,
#   'neu': 0.789,
#   'pos': 0.211,
#   'text': 'High key excited to be going back to UCSD 💙💛'},
#  {'compound': 0.5374,
#   'neg': 0.0,
#   'neu': 0.878,
#   'pos': 0.122,
#   'text': 'OMG!! Got THE CALL for lungs at 5:30am! Waiting at UCSD to make sure they are a go..if so I could have new lungs TODAY!! 😂😂🦋 #cysticfibrosis #trandplanttime'},
#  {'compound': 0.0,
#   'neg': 0.108,
#   'neu': 0.752,
#   'pos': 0.141,
#   'text': 'Did ya’ll know I was initially waitlisted at MIT and straight up rejected from UCSD for grad school. Just in case you were thinking about giving up.'},
#  {'compound': 0.5719,
#   'neg': 0.0,
#   'neu': 0.73,
#   'pos': 0.27,
#   'text': "UCSD women's soccer wins home opener as McManus eats pizza http://dlvr.it/Qhr6Qp "},
#  {'compound': 0.4201,
#   'neg': 0.0,
#   'neu': 0.877,
#   'pos': 0.123,
#   'text': 'i can’t believe that in a month summer manar and i will all being going to the same school... ucsd? more like tumblr university'},
#  {'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'text': '@UCSanDiego named No.1 public university in the nation by  Washington Monthly for its contributions to social mobility research and public service. @washmonthly #ucsd #TritonPride http://ow.ly/TKnC30lzFBs '},
#  {'compound': -0.6801,
#   'neg': 0.452,
#   'neu': 0.406,
#   'pos': 0.142,
#   'text': 'USC rejected me and UCSD accepted me so disappointed.'},
#  {'compound': 0.7345,
#   'neg': 0.0,
#   'neu': 0.744,
#   'pos': 0.256,
#   'text': "Summer's winding down ... how many new UCSD Bioengineering students become alums this coming year? Good luck to you guys!"},
#  {'compound': 0.2382,
#   'neg': 0.0,
#   'neu': 0.943,
#   'pos': 0.057,
#   'text': 'I can’t seem to find a good time to remind everyone that the inaugural #PedsICU Journal Club will commence on Sept. 18 at 7 central time. 10 pm on a Saturday isn’t it but I’ll RT later. '},
#  {'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'text': 'UCSD REINSTATED ME IT’S MODELO TIME'},
#  {'compound': 0.8091,
#   'neg': 0.1,
#   'neu': 0.537,
#   'pos': 0.363,
#   'text': 'Great opportunity to take the ATOM & ASSET trauma courses at the the @CFS_UCSD facility during #AAST2018 #wtc2018 at @UCSDsurgery '},
#  {'compound': 0.7717,
#   'neg': 0.0,
#   'neu': 0.705,
#   'pos': 0.295,
#   'text': 'Jumping for joy on this easy Monday. #laborday #holiday #sandiego #california @ UCSD - University of California San Diego https://www.instagram.com/p/BnRkQwEHJiu/?utm_source=ig_twitter_share&igshid=q4h7a4a4khwn …'},
#  {'compound': -0.1779,
#   'neg': 0.082,
#   'neu': 0.918,
#   'pos': 0.0,
#   'text': 'This is a weird story. Of note UCSD’s Athletic Director is Earl Edwards father of Orlando City GK Earl Edwards Jr.'},
#  {'compound': 0.6908,
#   'neg': 0.0,
#   'neu': 0.808,
#   'pos': 0.192,
#   'text': 'Second #NASPA proposal submitted. 😅 This one in collaboration with my dear friends and colleagues who co-organized the UC first-gen symposium hosted @UCSD. @AleceAnderson @ucfirstgen @UCdiverse #teamworkmakesthedreamwork'},
#  {'compound': 0.6801,
#   'neg': 0.0,
#   'neu': 0.682,
#   'pos': 0.318,
#   'text': 'Very interesting work from UCSD Neutrophil nanosponges soak up proteins that promote rheumatoid arthritis'},
#  {'compound': 0.5106,
#   'neg': 0.078,
#   'neu': 0.749,
#   'pos': 0.173,
#   'text': "Part one of our series by @UCSD_EDC's Dr. Walter Kaye Anorexia Current & Prior Research: Implications for Improved Treatment fom Eating Disorder Hope’s Virtual Conference “Anorexia Hope & Healing in 2018”"},
#  {'compound': 0.743,
#   'neg': 0.0,
#   'neu': 0.657,
#   'pos': 0.343,
#   'text': "U of R Men's Water Polo Tops Chapman to Highlight Day Two of UCSD Triton Invite http://www.goredlands.com/x/zopca  #URDawgs #TimeToShine"},
#  {'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'text': '📈  405.60 parts per million (ppm) #CO2 in the atmosphere on September 2 2018  🔗  #Scripps #UCSD Mauna Loa data & graphic: https://scripps.ucsd.edu/programs/keelingcurve/ …  👥  Also view daily CO2 updates at https://www.co2.earth/daily-co2 '},
#  {'compound': 0.8977,
#   'neg': 0.0,
#   'neu': 0.791,
#   'pos': 0.209,
#   'text': 'Thank you to all the teams & supporters who made it down to La Jolla for the annual #TritonInvite. It is always an exciting event & we are grateful to host the start of the 2018 season. The next home game for @UCSDTritonsMWP will be September 19th at 6pm against @LBSUWaterPolo!'},
#  {'compound': 0.3612,
#   'neg': 0.0,
#   'neu': 0.878,
#   'pos': 0.122,
#   'text': "I can't believe I have the privilege to say that I am a student in the Jacob Sartorius School of Engineering at UCSD.  🤧"},
#  {'compound': 0.5707,
#   'neg': 0.0,
#   'neu': 0.802,
#   'pos': 0.198,
#   'text': 'Congrats to junior forward Brandon Angel on his offer from future Big West school UCSD! #GoFalcons'},
#  {'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'text': 'One of my first #retina paintings that now hangs at #UCSD. Commissioned in 2012. #goldleaf #art https://buff.ly/LGtoGE '},
#  {'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'text': "More on the men finishing second and the women taking third at today's Mark Covert Classic to open the season. http://www.ucsdtritons.com/ViewArticle.dbml?DB_OEM_ID=5800&ATCLID=211770300 … #GoTritons 🔱"},
#  {'compound': 0.7896,
#   'neg': 0.0,
#   'neu': 0.845,
#   'pos': 0.155,
#   'text': '#PHMFellowsJC is hosting our first journal club this month too! Tues Sept 11 9 pm EST. Would love to have #PedsICU join us to discuss the recently published @JAMA_current paper on the NY sepsis mandate. More details to come this Tuesday!'},
#  {'compound': 0.8091,
#   'neg': 0.1,
#   'neu': 0.537,
#   'pos': 0.363,
#   'text': 'Great opportunity to take the ATOM & ASSET trauma courses at the the @CFS_UCSD facility during #AAST2018 #wtc2018 at @UCSDsurgery '},
#  {'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'text': 'Live from India - my travel blog has returned. This goes back to 2005 and includes all my China travels that were long ago cross posted to the Node: http://phdtraveler.blogspot.com '},
#  {'compound': 0.2732,
#   'neg': 0.0,
#   'neu': 0.811,
#   'pos': 0.189,
#   'text': '2019 G Bryce Pope (Torrey Pines) has committed to UCSD. #gpnation'},
#  {'compound': 0.5719,
#   'neg': 0.0,
#   'neu': 0.879,
#   'pos': 0.121,
#   'text': 'Did you know that @UCSDHealth #surgeons have performed >3900 #pulmonary thromboendarterectomy procedures which remove deadly clots from the lungs. Thank you Dr. Michael Madani for leading the program & helping patients live longer healthier lives. @STS_CTsurgery @annalsthorsurg'},
#  {'compound': 0.4926,
#   'neg': 0.0,
#   'neu': 0.775,
#   'pos': 0.225,
#   'text': 'The new MZmine-GNPS tutorial is making my day - thanks @GNPS_UCSD! #RealTimeChem #chemtwitter '},
#  {'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'text': 'Stats 101 Deep Thoughts #pedsICU'},
#  {'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'text': 'Classroom management @UHS_UCSD. Setting expectations for different types of student groupings. '}]

# %%
Table.from_records(tweetSentiments)
# Out:
# compound | neg   | neu   | pos   | text
# 0.6369   | 0     | 0.682 | 0.318 | UCSD ranked 7th best school in US by Washington Monthly
# -0.4215  | 0.237 | 0.763 | 0     | it physically pains me that UCSD doesn’t have a football ...
# 0        | 0     | 1     | 0     | A card mis-judged a parking space and over-ran a parking ...
# 0.8659   | 0     | 0.72  | 0.28  | Almost 50% increase in #PedsICU engagement from last wee ...
# 0.0772   | 0     | 0.954 | 0.046 | here’s a tinge of classism in saying SDSU should make do ...
# 0.4588   | 0     | 0.885 | 0.115 | This past weekend we observed the 25th anniversary of th ...
# -0.6801  | 0.424 | 0.443 | 0.133 | I HATE UCSD SO MUCH THEYRE SO ANNOYING OHHHHH MY GOD
# -0.5319  | 0.231 | 0.657 | 0.112 | LMFAOOO UCSD JUST CALLED ME ASKING IF I COULD MAKE A $25 ...
# 0.6369   | 0     | 0.682 | 0.318 | I chose UCSD because it has the best fb meme group
# 0.34     | 0     | 0.789 | 0.211 | High key excited to be going back to UCSD 💙💛
# ... (30 rows omitted)

# %% [markdown]
# # Next Steps
#
# * load the file of "internet research agency" tweets (a small sample) and explore!
#     - `data/ira.csv`

# %%
internet_research_agency = Table().read_table('data/ira.csv')
internet_research_agency
# Out:
# 3906258 | ea85ac8be1e8ab479064ca4c0fe3ac6587f76b1ef974526887856fe299d3f2c0 | 2016-11-16 09:04 | The Best Exercise To Lose Belly Fat In 2 weeks  https://t.co/oHFToG7rh6 #Exercise #LoseBellyFat #CatTV #TeenWolf… https://t.co/b4pr9gEx38
# 1051443 | 8e58ab0f46d273103d9e71aa92cdaffb6e330ec7d15ae5fa79c825e2d6f291bf | 2016-12-24 04:31 | RT @Philanthropy: Dozens of ‘hate groups’ have charity status, Chronicle study finds https://t.co/FxUBBHNlKy
# 2823399 | Room Of Rumor                                                    | 2016-08-18 20:26 | Artificial intelligence can find, map poverty, researchers say  #tech
# 272878  | San Francisco Daily                                              | 2016-03-18 19:28 | Uber balks at rules proposed by world’s busiest airport  #news
# 7697802 | 41bb9ae5991f53996752a0ab8dd36b543821abca8d5aed8980383c82378e7518 | 2016-07-30 15:44 | RT @dirtroaddiva1: #IHatePokemonGoBecause he  didn't let me do "that" for a Klondike bar.    Screw you Pokemon.  #PokesAreJokes. http ...
# 1409274 | New York City Today                                              | 2016-01-04 19:02 | Chick-fil-A remains closed after health violations  #health
# 2973541 | ce7b9f8c86dfbf9b2bd03eda62f0d42ac1c2b1b593ba0b0b052210acf652f896 | 2016-05-20 14:56 | RT @SenSanders: We cannot afford to wait to address this public health crisis. We must quickly fund efforts to stop Zika's spread. ht ...
# 1042655 | Andy Sparks                                                      | 2016-04-13 14:52 | RT @MatthewGellert: #IWouldPreferToForget that the two leading Republican candidates are an ignorant bully and an ignorant preacher.
# 7838616 | 40bd0ff013b85c7646ca07ad238bc4dc865ce2cc87034af6e7884e69481f6422 | 2016-10-08 10:19 | RT @rapstationradio: #NowPlaying: RJ (OMMIO) "From Nothing (Prod. By Davo)" #rap #hiphop #music https://t.co/8TJZ3vVCxs
# 8005939 | 0512ea612cfe45a7d9c8c0fd42466e8a8068a6fb3efb34baf7e7be40da578539 | 2016-08-15 09:57 | Hill Street Vida Blues. #AthleticsTVShows @susanslusser
# 6262477 | ef983249ef6ed5de427c4dc19ad6d966c6cf572c2505e44142e7e7261f917ae6 | 2016-09-09 18:39 | RT @c982f7295cf57508a8d39bae6310c9546492d4105cac8d18cc798e56f7573376: All you wanted to know about Hillary #HillaryRottenClinton  htt ...
# ... (89989 rows omitted)

# %%
internet_research_agency
